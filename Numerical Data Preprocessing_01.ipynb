# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/Users/nidagallusandeep/Downloads/employee_data.csv")

# %%
df.head()
# Out:
#    Employee_ID   Age  Experience  Salary
# 0          101  22.0         1.0   25000
# 1          102  25.0         3.0   35000
# 2          103  28.0         5.0   45000
# 3          104  30.0         NaN   55000
# 4          105  35.0         8.0   70000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  10 non-null     int64
#  1   Age          9 non-null      float64
#  2   Experience   9 non-null      float64
#  3   Salary       10 non-null     int64
# dtypes: float64(2), int64(2)
# memory usage: 452.0 bytes

# %%
df.shape
# Out:
# (10, 4)

# %%
df.isnull().sum()
# Out:
# Employee_ID    0
# Age            1
# Experience     1
# Salary         0
# dtype: int64

# %% [markdown]
# # Handle Missing Values

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())
df["Experience"]=df["Experience"].fillna(df["Experience"].mean())

# %% [markdown]
# # Check Outliers

# %%
plt.boxplot(df["Salary"])
plt.title("Salary Outliers")
plt.show()

# %% [markdown]
# # Select Numerical Features

# %%
X=df[["Age","Experience","Salary"]]
print(X)
# Out:
#          Age  Experience  Salary
# 0  22.000000    1.000000   25000
# 1  25.000000    3.000000   35000
# 2  28.000000    5.000000   45000
# 3  30.000000    8.666667   55000
# 4  35.000000    8.000000   70000
# 5  40.000000   12.000000   90000
# 6  45.000000   15.000000  120000
# 7  50.000000   20.000000  500000
# 8  33.555556   10.000000   80000
# 9  27.000000    4.000000   40000

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaler=scaler.fit_transform(X)
X_scaler
# Out:
# array([[-1.34492254, -1.38143744, -0.603839  ],
#        [-0.99575996, -1.02106246, -0.52929098],
#        [-0.64659738, -0.66068747, -0.45474295],
#        [-0.41382232,  0.        , -0.38019493],
#        [ 0.16811532, -0.120125  , -0.26837289],
#        [ 0.75005296,  0.60062498, -0.11927684],
#        [ 1.33199059,  1.14118745,  0.10436723],
#        [ 1.91392823,  2.04212492,  2.93719218],
#        [ 0.        ,  0.24024999, -0.19382486],
#        [-0.7629849 , -0.84087497, -0.49201696]])

# %% [markdown]
# # Create DataFrame

# %%
scaler_df=pd.DataFrame(X_scaler,columns=["Age","Experience","Salary"])
print(scaler_df)
# Out:
#         Age  Experience    Salary
# 0 -1.344923   -1.381437 -0.603839
# 1 -0.995760   -1.021062 -0.529291
# 2 -0.646597   -0.660687 -0.454743
# 3 -0.413822    0.000000 -0.380195
# 4  0.168115   -0.120125 -0.268373
# 5  0.750053    0.600625 -0.119277
# 6  1.331991    1.141187  0.104367
# 7  1.913928    2.042125  2.937192
# 8  0.000000    0.240250 -0.193825
# 9 -0.762985   -0.840875 -0.492017
