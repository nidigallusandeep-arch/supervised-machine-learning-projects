# %% [markdown]
# # Problem Statement: Customer Purchase Prediction Using KNN
# - Objective
# - Build a Machine Learning classification model using K-Nearest Neighbors (KNN) to predict whether a customer will purchase a product or not based on their personal and behavioral information.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/Users/nidagallusandeep/Downloads/knn_classification_customer_data_1000.csv")

# %%
df.head()
# Out:
#    Age  Annual_Income  Credit_Score  Years_Employed  Purchase_Count  \
# 0   56          69376           605              16              12
# 1   46          65587           569               4              22
# 2   32          56976           584              11              25
# 3   60         124587           526              10              17
# 4   25         147534           680              14              29
#
#    Website_Visits Will_Purchase
# 0              11            No
# 1              46           Yes
# 2              34           Yes
# 3              28           Yes
# 4               5           Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             1000 non-null   int64
#  1   Annual_Income   1000 non-null   int64
#  2   Credit_Score    1000 non-null   int64
#  3   Years_Employed  1000 non-null   int64
#  4   Purchase_Count  1000 non-null   int64
#  5   Website_Visits  1000 non-null   int64
#  6   Will_Purchase   1000 non-null   object
# dtypes: int64(6), object(1)
# memory usage: 54.8+ KB

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.describe()
# Out:
#                Age  Annual_Income  Credit_Score  Years_Employed  \
# count  1000.000000    1000.000000   1000.000000      1000.00000
# mean     41.575000   85278.565000    576.994000        10.02000
# std      13.765677   38161.672225    158.023826         6.06006
# min      18.000000   20060.000000    300.000000         0.00000
# 25%      30.000000   52919.000000    442.000000         5.00000
# 50%      42.000000   85005.500000    578.000000        10.00000
# 75%      53.000000  117745.000000    713.000000        15.00000
# max      65.000000  149972.000000    849.000000        20.00000
#
#        Purchase_Count  Website_Visits
# count     1000.000000     1000.000000
# mean        15.468000       25.815000
# std          8.960986       14.367017
# min          0.000000        1.000000
# 25%          8.000000       13.000000
# 50%         16.000000       25.000000
# 75%         23.000000       39.000000
# max         30.000000       50.000000

# %%
df.isnull().sum()
# Out:
# Age               0
# Annual_Income     0
# Credit_Score      0
# Years_Employed    0
# Purchase_Count    0
# Website_Visits    0
# Will_Purchase     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
X=df.drop("Will_Purchase",axis=1)
y=df["Will_Purchase"]

# %% [markdown]
# # Convert Yes/No to 1/0

# %%
y = y.map({
    "No": 0,
    "Yes": 1
})

print(y.head())
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Will_Purchase, dtype: int64

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.2,random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (200, 6)
# (800, 6)
# (200,)
# (800,)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaler=scaler.fit_transform(X_train)
X_test_scaler=scaler.transform(X_test)

# %% [markdown]
# # Create KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaler,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Prediction
y_pred=knn.predict(X_test_scaler)
print(y_pred[:10])
# Out:
# [0 1 0 1 0 1 0 0 0 0]

# %% [markdown]
# # Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.6525

# %%
print("Accuracy:", accuracy * 100, "%")
# Out:
# Accuracy: 65.25 %

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import consensus_score,confusion_matrix,classification_report

# %%
cm=confusion_matrix(y_test,y_pred)
print("confusion_matrix:",cm)
# Out:
# confusion_matrix: [[258 144]
#  [134 264]]

# %%
import matplotlib.pyplot as plt
plt.imshow(cm)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.colorbar()
plt.show()

# %% [markdown]
# # Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.64      0.65       402
#            1       0.65      0.66      0.66       398
#
#     accuracy                           0.65       800
#    macro avg       0.65      0.65      0.65       800
# weighted avg       0.65      0.65      0.65       800
